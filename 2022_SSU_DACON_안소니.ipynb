# %% [markdown]
# # EDA

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

#데이터 읽기
train = pd.read_csv('data/train.csv')
test = pd.read_csv('data/test.csv')

print(f'data set은 {train.shape[1]} 개의 feature를 가진 {train.shape[0]} 개의 데이터 샘플로 이루어져 있습니다.')

# 데이터의 최상단 5 줄을 표시합니다.
train.head()
# Out:
# data set은 11 개의 feature를 가진 1015 개의 데이터 샘플로 이루어져 있습니다.
#    id                          title  odometer location    isimported  \
# 0   0                   Toyota RAV 4     18277   Lagos   Foreign Used
# 1   1            Toyota Land Cruiser        10    Lagos          New
# 2   2  Land Rover Range Rover Evoque     83091    Lagos  Foreign Used
# 3   3                   Lexus ES 350     91524    Lagos  Foreign Used
# 4   4                   Toyota Venza     94177    Lagos  Foreign Used
#
#            engine transmission    fuel  paint  year    target
# 0  4-cylinder(I4)    automatic  petrol    Red  2016  13665000
# 1  4-cylinder(I4)    automatic  petrol  Black  2019  33015000
# 2  6-cylinder(V6)    automatic  petrol    Red  2012   9915000
# 3  4-cylinder(I4)    automatic  petrol   Gray  2007   3815000
# 4  6-cylinder(V6)    automatic  petrol    Red  2010   7385000

# %%
# target 분포 확인 -> 편차가 심함.
plt.figure(figsize=(10,10))
plt.hist(train['target'], bins=50)
plt.title('Target Histogram')
plt.show()

# %%
# 로그변환을 적용한 target 분포 확인 -> 정규분포와 가까운 모양
log_target = np.log(train['target'])

plt.figure(figsize=(10,10))
plt.hist(log_target, bins=50)
plt.title('Target Histogram with logarithm')
plt.show()

# %%
train[train['year'] < 1900]
# Out:
#       id                title  odometer location    isimported  \
# 415  415  Mercedes-Benz ATEGO    403461    Lagos  Locally used
# 827  827     Mercedes-Benz/52    510053    Lagos  Locally used
#
#              engine transmission    fuel  paint  year    target
# 415  4-cylinder(I4)       manual  diesel  white  1218   6015000
# 827  6-cylinder(V6)       manual  diesel  white  1217  75015000

# %%
#이상값 삭제
train = train[train['year'] > 1900]
train.shape
# Out:
# (1013, 11)

# %%
train = train.drop('id', axis = 1).reset_index().drop('index', axis = 1).reset_index().rename({'index':'id'}, axis = 'columns')

# %%
#outlier 삭제
numeric_fts = ['odometer', 'year']
outlier_ind = []
for i in numeric_fts:
  Q1 = np.percentile(train[i],25)
  Q3 = np.percentile(train[i],75)
  IQR = Q3-Q1
  outlier_list = train[(train[i] < Q1 - IQR * 1.5) | (train[i] > Q3 + IQR * 1.5)].index
  outlier_ind.extend(outlier_list)

# %%
# Drop outliers
train = train.drop(outlier_ind, axis = 0).reset_index(drop = True)

# %%
train.shape
# Out:
# (975, 11)

# %%
train.head()
# Out:
#    id                          title  odometer location    isimported  \
# 0   0                   Toyota RAV 4     18277   Lagos   Foreign Used
# 1   1            Toyota Land Cruiser        10    Lagos          New
# 2   2  Land Rover Range Rover Evoque     83091    Lagos  Foreign Used
# 3   3                   Lexus ES 350     91524    Lagos  Foreign Used
# 4   4                   Toyota Venza     94177    Lagos  Foreign Used
#
#            engine transmission    fuel  paint  year    target
# 0  4-cylinder(I4)    automatic  petrol    Red  2016  13665000
# 1  4-cylinder(I4)    automatic  petrol  Black  2019  33015000
# 2  6-cylinder(V6)    automatic  petrol    Red  2012   9915000
# 3  4-cylinder(I4)    automatic  petrol   Gray  2007   3815000
# 4  6-cylinder(V6)    automatic  petrol    Red  2010   7385000

# %%
#파생변수 brand 생성
train['title'].value_counts()[:20]
# Out:
# Toyota Camry            126
# Toyota Corolla          108
# Toyota Highlander        49
# Toyota Sienna            46
# Toyota RAV 4             40
# Honda Accord             36
# Lexus RX 350             33
# Lexus ES 350             24
# Lexus GX 460             16
# Toyota Venza             16
# Honda Pilot              15
# Lexus LX 570             14
# Toyota Avalon            13
# Mercedes-Benz ML 350     13
# Toyota 4-Runner          12
# Toyota Tacoma            12
# Mercedes-Benz E 350      12
# Mercedes-Benz GL 450     12
# Ford Explorer            12
# Toyota Matrix            11
# Name: title, dtype: int64

# %%
train['title'].apply(lambda x : x.split(" ")[0])
# Out:
# 0             Toyota
# 1             Toyota
# 2               Land
# 3              Lexus
# 4             Toyota
# 5             Toyota
# 6               Land
# 7            Pontiac
# 8             Toyota
# 9              Lexus
# 10              Ford
# 11             Honda
# 12             Volvo
# 13             Lexus
# 14               BMW
# 15          Infiniti
# 16             Honda
# 17     Mercedes-Benz
# 18            Toyota
# 19           Hyundai
# 20             Lexus
# 21               BMW
# 22            Toyota
# 23            Toyota
# 24            Toyota
# 25             Honda
# 26            Toyota
# 27            Toyota
# 28             Honda
# 29             Honda
#            ...
# 945           Toyota
# 946    Mercedes-Benz
# 947    Mercedes-Benz
# 948            Lexus
# 949           Toyota
# 950            Lexus
# 951           Toyota
# 952       Volkswagen
# 953           Toyota
# 954           Toyota
# 955           Toyota
# 956             Land
# 957           Toyota
# 958           Toyota
# 959            Lexus
# 960            Lexus
# 961           Toyota
# 962            Honda
# 963           Toyota
# 964             Ford
# 965            Lexus
# 966           Toyota
# 967            Honda
# 968            Honda
# 969           Toyota
# 970           Toyota
# 971           Toyota
# 972           Toyota
# 973            Lexus
# 974              DAF
# Name: title, Length: 975, dtype: object

# %%
train['brand'] = train['title'].apply(lambda x : x.split(" ")[0])
train.head()
# Out:
#    id                          title  odometer location    isimported  \
# 0   0                   Toyota RAV 4     18277   Lagos   Foreign Used
# 1   1            Toyota Land Cruiser        10    Lagos          New
# 2   2  Land Rover Range Rover Evoque     83091    Lagos  Foreign Used
# 3   3                   Lexus ES 350     91524    Lagos  Foreign Used
# 4   4                   Toyota Venza     94177    Lagos  Foreign Used
#
#            engine transmission    fuel  paint  year    target   brand
# 0  4-cylinder(I4)    automatic  petrol    Red  2016  13665000  Toyota
# 1  4-cylinder(I4)    automatic  petrol  Black  2019  33015000  Toyota
# 2  6-cylinder(V6)    automatic  petrol    Red  2012   9915000    Land
# 3  4-cylinder(I4)    automatic  petrol   Gray  2007   3815000   Lexus
# 4  6-cylinder(V6)    automatic  petrol    Red  2010   7385000  Toyota

# %%
train['brand'].value_counts()
# Out:
# Toyota            464
# Lexus             121
# Mercedes-Benz     102
# Honda              78
# Ford               34
# Hyundai            23
# Nissan             21
# Land               19
# Kia                14
# Volkswagen         11
# BMW                10
# Acura               9
# Mazda               8
# Volvo               7
# Infiniti            5
# Chevrolet           5
# Mitsubishi          4
# GAC                 4
# Porsche             4
# Peugeot             3
# Scania              3
# Pontiac             3
# Jaguar              3
# Man                 2
# Isuzu               2
# DAF                 2
# MINI                2
# IVECO               1
# JMC                 1
# MAN-VOLKSWAGEN      1
# ALPINA              1
# Bentley             1
# Rolls-Royce         1
# Jeep                1
# Iveco               1
# IVM                 1
# Mack                1
# Lincoln             1
# GMC                 1
# Name: brand, dtype: int64

# %%
len(train['brand'].unique())
# Out:
# 39

# %%
#test도 brand 추가
test['brand'] = test['title'].apply(lambda x : x.split(" ")[0])
test.head()
# Out:
#    id                title  odometer location    isimported          engine  \
# 0   0  Mercedes-Benz C 300      1234    Abuja          New   4-cylinder(I4)
# 1   1         Honda Accord     29938    Abuja  Foreign Used  4-cylinder(I4)
# 2   2  Mercedes-Benz S 550     87501    Lagos  Foreign Used  4-cylinder(I4)
# 3   3        Toyota Sienna    180894    Lagos  Locally used  6-cylinder(V6)
# 4   4         Toyota Hiace    104814    Lagos  Foreign Used  4-cylinder(I4)
#
#   transmission    fuel      paint  year          brand
# 0    automatic  petrol      White  2017  Mercedes-Benz
# 1    automatic  petrol      White  2013          Honda
# 2    automatic  petrol      Black  2012  Mercedes-Benz
# 3    automatic  petrol  Dark Grey  2001         Toyota
# 4    automatic  petrol      White  2000         Toyota

# %%
print(train['brand'].unique())
print("#fts :", len(train['brand'].unique()), '\n')
print(test['brand'].unique())
print("#fts :", len(test['brand'].unique()), '\n')
# Out:
# ['Toyota' 'Land' 'Lexus' 'Pontiac' 'Ford' 'Honda' 'Volvo' 'BMW' 'Infiniti'
#  'Mercedes-Benz' 'Hyundai' 'Jaguar' 'Mitsubishi' 'Nissan' 'Chevrolet'
#  'Mazda' 'Lincoln' 'Kia' 'Acura' 'DAF' 'Man' 'Isuzu' 'IVM' 'Porsche'
#  'MINI' 'GMC' 'Iveco' 'Scania' 'Volkswagen' 'GAC' 'IVECO' 'Mack' 'Peugeot'
#  'Rolls-Royce' 'MAN-VOLKSWAGEN' 'Jeep' 'ALPINA' 'Bentley' 'JMC']
# #fts : 39
#
# ['Mercedes-Benz' 'Honda' 'Toyota' 'Iveco' 'Lexus' 'Nissan' 'Volkswagen'
#  'Jeep' 'Ford' 'BMW' 'Mack' 'Land' 'Hyundai' 'Peugeot' 'Volvo' 'Infiniti'
#  'Acura' 'Man' 'Fiat' 'MINI' 'DAF' 'Mazda' 'Porsche' 'Mitsubishi'
#  'Chevrolet' 'Kia' 'Pontiac' 'Rolls-Royce']
# #fts : 28

# %%
brand_list = train[['brand', 'target']].groupby(['brand'], as_index=False).mean().sort_values(by='target', ascending=True)
brand_list = brand_list.reset_index(drop=True)

# %%
brand_list
# Out:
#              brand        target
# 0              GAC  1.490000e+06
# 1           Nissan  1.986667e+06
# 2            Mazda  2.078750e+06
# 3       Volkswagen  2.094091e+06
# 4          Peugeot  2.125000e+06
# 5             Jeep  2.515000e+06
# 6           Jaguar  2.665000e+06
# 7          Pontiac  2.715000e+06
# 8              Kia  2.817857e+06
# 9              IVM  2.890000e+06
# 10      Mitsubishi  3.420000e+06
# 11         Hyundai  3.892826e+06
# 12           Isuzu  4.015000e+06
# 13           Acura  4.082000e+06
# 14           Volvo  4.155714e+06
# 15           Honda  4.394173e+06
# 16         Lincoln  4.415000e+06
# 17             GMC  5.515000e+06
# 18            MINI  5.540000e+06
# 19           IVECO  6.015000e+06
# 20            Ford  6.318456e+06
# 21  MAN-VOLKSWAGEN  6.340000e+06
# 22          Toyota  6.378490e+06
# 23       Chevrolet  7.233000e+06
# 24          Scania  7.930000e+06
# 25            Mack  8.015000e+06
# 26             DAF  8.515000e+06
# 27          ALPINA  9.065000e+06
# 28             JMC  9.365000e+06
# 29           Iveco  1.001500e+07
# 30             Man  1.026500e+07
# 31   Mercedes-Benz  1.337353e+07
# 32           Lexus  1.408227e+07
# 33         Porsche  1.426500e+07
# 34             BMW  1.527900e+07
# 35        Infiniti  1.616000e+07
# 36         Bentley  2.801500e+07
# 37            Land  2.939868e+07
# 38     Rolls-Royce  1.500150e+08

# %%
#브랜드의 등급을 살리기 위해 따로 숫자를 준 다음에 Numeric 데이터로 학습할 것.
for i,br in enumerate(brand_list.brand):
    train = train.replace({
    br : 10*i,
    })
    
    test = test.replace({
    br : 10*i,
    'Fiat' : 0,
    })

# %%
train[['brand', 'target']].groupby(['brand'], as_index=False).mean().sort_values(by='target', ascending=True)
# Out:
#     brand        target
# 0       0  1.490000e+06
# 1      10  1.986667e+06
# 2      20  2.078750e+06
# 3      30  2.094091e+06
# 4      40  2.125000e+06
# 5      50  2.515000e+06
# 6      60  2.665000e+06
# 7      70  2.715000e+06
# 8      80  2.817857e+06
# 9      90  2.890000e+06
# 10    100  3.420000e+06
# 11    110  3.892826e+06
# 12    120  4.015000e+06
# 13    130  4.082000e+06
# 14    140  4.155714e+06
# 15    150  4.394173e+06
# 16    160  4.415000e+06
# 17    170  5.515000e+06
# 18    180  5.540000e+06
# 19    190  6.015000e+06
# 20    200  6.318456e+06
# 21    210  6.340000e+06
# 22    220  6.378490e+06
# 23    230  7.233000e+06
# 24    240  7.930000e+06
# 25    250  8.015000e+06
# 26    260  8.515000e+06
# 27    270  9.065000e+06
# 28    280  9.365000e+06
# 29    290  1.001500e+07
# 30    300  1.026500e+07
# 31    310  1.337353e+07
# 32    320  1.408227e+07
# 33    330  1.426500e+07
# 34    340  1.527900e+07
# 35    350  1.616000e+07
# 36    360  2.801500e+07
# 37    370  2.939868e+07
# 38    380  1.500150e+08

# %%
#train 또는 test 데이터세트에서 공통적으로 존재하지 않은 경우 가장 가까운 실린더 갯수로 통합
set(set(train.engine.unique()) | set(test.engine.unique())) - set(set(train.engine.unique()) & set(test.engine.unique()))
# Out:
# {'12-cylinder(V12)', '4-cylinder(H4)'}

# %%
train = train.replace({'4-cylinder(H4)' : '4-cylinder(I4)'})

# %%
test[test.engine == '12-cylinder(V12)']
# Out:
#       id                  title  odometer location isimported  \
# 142  142  Mercedes-Benz Maybach      6758    Lagos       New
#
#                engine transmission    fuel  paint  year brand
# 142  12-cylinder(V12)    automatic  petrol  Black  2019   310

# %%
test = test.replace({'12-cylinder(V12)' : '8-cylinder(V8)'})

# %%
print('------------- train -------------')
print(sorted(train.engine.unique()))

print('\n\n------------- test -------------')
print(sorted(test.engine.unique()))
# Out:
# ------------- train -------------
# ['2-cylinder(I2)', '3-cylinder(I3)', '4-cylinder(I4)', '5-cylinder(I5)', '6-cylinder(I6)', '6-cylinder(V6)', '8-cylinder(V8)']
#
#
# ------------- test -------------
# ['2-cylinder(I2)', '3-cylinder(I3)', '4-cylinder(I4)', '5-cylinder(I5)', '6-cylinder(I6)', '6-cylinder(V6)', '8-cylinder(V8)']

# %%
engine_re = train[['engine', 'target']].groupby(['engine'], as_index=False).mean().sort_values(by='target', ascending=False)
engine_re = engine_re.reset_index(drop=True)

# %%
engine_re
# Out:
#            engine        target
# 0  8-cylinder(V8)  2.280010e+07
# 1  6-cylinder(I6)  7.969522e+06
# 2  6-cylinder(V6)  7.682515e+06
# 3  4-cylinder(I4)  7.471240e+06
# 4  5-cylinder(I5)  3.815000e+06
# 5  3-cylinder(I3)  3.138333e+06
# 6  2-cylinder(I2)  3.015000e+06

# %%
#엔진(실린더) 등급 살리기
train = train.replace({
    '2-cylinder(I2)' : 10,
    '3-cylinder(I3)' : 20,
    '5-cylinder(I5)' : 30,
    '4-cylinder(I4)' : 40,
    '6-cylinder(V6)' : 50,
    '6-cylinder(I6)' : 60,
    '8-cylinder(V8)' : 70
})

test = test.replace({
    '2-cylinder(I2)' : 10,
    '3-cylinder(I3)' : 20,
    '5-cylinder(I5)' : 30,
    '4-cylinder(I4)' : 40,
    '6-cylinder(V6)' : 50,
    '6-cylinder(I6)' : 60,
    '8-cylinder(V8)' : 70
})

# %%
print('------------- train -------------')
print(sorted(train.engine.unique()))

print('\n\n------------- test -------------')
print(sorted(test.engine.unique()))
# Out:
# ------------- train -------------
# [10, 20, 30, 40, 50, 60, 70]
#
#
# ------------- test -------------
# [10, 20, 30, 40, 50, 60, 70]

# %%
#train의 paint 값 정제 시작
train['paint'].value_counts()[:20]
# Out:
# Black        287
# White        114
# Silver       101
# Grey          82
# Blue          69
# Red           52
# Dark Grey     44
# Gold          36
# Green         17
# Gray          17
# Brown         16
# Black         15
# white         15
# Dark Blue     14
# Wine           8
# Silver         5
# Sliver         4
# Purple         3
# blue           3
# Ash            3
# Name: paint, dtype: int64

# %%
import re 

def clean_text(texts): 
    corpus = [] 
    for i in range(0, len(texts)): 
        review = re.sub(r'[@%\\*=()/~#&\+á?\xc3\xa1\-\|\.\:\;\!\-\,\_\~\$\'\"\n\]\[\>\<]', '',texts[i]) #@%*=()/+ 와 같은 문장부호 제거
        review = re.sub(r'\d+','',review)#숫자 제거
        review = review.lower() #소문자 변환
        review = re.sub(r'\s+', ' ', review) #extra space 제거
        review = re.sub(r'<[^>]+>','',review) #Html tags 제거
        review = re.sub(r'\s+', ' ', review) #spaces 제거
        review = re.sub(r"^\s+", '', review) #space from start 제거
        review = re.sub(r'\s+$', '', review) #space from the end 제거
        review = re.sub(r'_', ' ', review) #space from the end 제거
        #review = re.sub(r'l', '', review)
        corpus.append(review) 
        
    return corpus

# %%
temp = clean_text(train['paint']) #메소드 적용
train['paint'] = temp

# %%
print('paint의 unique 카테고리 개수 : ', len(train['paint'].unique()))
# Out:
# paint의 unique 카테고리 개수 :  49

# %%
train['paint'].value_counts()[:20]
# Out:
# black        305
# white        132
# silver       107
# grey          84
# blue          74
# red           54
# dark grey     45
# gold          39
# green         19
# gray          18
# dark blue     17
# brown         16
# wine           9
# sliver         4
# dark ash       4
# cream          4
# ash            3
# purple         3
# yellow         3
# whiteblue      2
# Name: paint, dtype: int64

# %%
#오타 수정 및 대표색상으로 바꾸기
train['paint'] = train['paint'] = train['paint'].apply(lambda x : 'blue' if x.find('blue') >= 0 else x)
train['paint'] = train['paint'] = train['paint'].apply(lambda x : 'red' if x.find('red') >= 0 else x)
train['paint'] = train['paint'] = train['paint'].apply(lambda x : 'green' if x.find('green') >= 0 else x)
train['paint'] = train['paint'] = train['paint'].apply(lambda x : 'white' if x.find('white') >= 0 else x)
train['paint'] = train['paint'] = train['paint'].apply(lambda x : 'grey' if x.find('grey') >= 0 else x)
train['paint'] = train['paint'] = train['paint'].apply(lambda x : 'grey' if x.find('gery') >= 0 else x)
train['paint'] = train['paint'] = train['paint'].apply(lambda x : 'grey' if x.find('gray') >= 0 else x)
train['paint'] = train['paint'] = train['paint'].apply(lambda x : 'ash' if x.find('ash') >= 0 else x)
train['paint'] = train['paint'] = train['paint'].apply(lambda x : 'brown' if x.find('brown') >= 0 else x)
train['paint'] = train['paint'] = train['paint'].apply(lambda x : 'silver' if x.find('silver') >= 0 else x)
train['paint'] = train['paint'] = train['paint'].apply(lambda x : 'silver' if x.find('sliver') >= 0 else x)
train['paint'] = train['paint'] = train['paint'].apply(lambda x : 'black' if x.find('black') >= 0 else x)
train['paint'] = train['paint'] = train['paint'].apply(lambda x : 'gold' if x.find('gold') >= 0 else x)
train['paint'] = train['paint'] = train['paint'].apply(lambda x : 'wine' if x.find('whine') >= 0 else x)

# %%
train['paint'].value_counts()
# Out:
# black     307
# grey      153
# white     136
# silver    114
# blue      100
# red        56
# gold       39
# green      20
# brown      17
# wine       10
# ash         8
# cream       4
# purple      3
# yellow      3
# maroon      2
# milk        2
# beige       1
# Name: paint, dtype: int64

# %%
print('paint의 unique 카테고리 개수 : ', len(train['paint'].value_counts()))
# Out:
# paint의 unique 카테고리 개수 :  17

# %%
sorted(train.paint.unique())
# Out:
# ['ash',
#  'beige',
#  'black',
#  'blue',
#  'brown',
#  'cream',
#  'gold',
#  'green',
#  'grey',
#  'maroon',
#  'milk',
#  'purple',
#  'red',
#  'silver',
#  'white',
#  'wine',
#  'yellow']

# %%
#test의 paint도 값 정제
temp2 = clean_text(test['paint'])
test['paint'] = temp2
print('test data에서 paint의 unique 카테고리 개수 : ', len(test['paint'].unique()))
# Out:
# test data에서 paint의 unique 카테고리 개수 :  30

# %%
sorted(test.paint.unique())
# Out:
# ['ash',
#  'beige',
#  'blac',
#  'black',
#  'blue',
#  'brown',
#  'classic silver metf',
#  'cream',
#  'dark ash',
#  'dark blue',
#  'dark green',
#  'dark grey',
#  'gold',
#  'golf',
#  'gray',
#  'green',
#  'grey',
#  'grey and black',
#  'indigo ink pearl',
#  'light grey',
#  'maroon',
#  'mint green',
#  'navy blue',
#  'red',
#  'silver',
#  'sliver',
#  'white',
#  'white and green',
#  'wine',
#  'yellow']

# %%
test['paint'] = test['paint'] = test['paint'].apply(lambda x : 'blue' if x.find('blue') >= 0 else x)
test['paint'] = test['paint'] = test['paint'].apply(lambda x : 'red' if x.find('red') >= 0 else x)
test['paint'] = test['paint'] = test['paint'].apply(lambda x : 'green' if x.find('green') >= 0 else x)
test['paint'] = test['paint'] = test['paint'].apply(lambda x : 'white' if x.find('white') >= 0 else x)
test['paint'] = test['paint'] = test['paint'].apply(lambda x : 'grey' if x.find('grey') >= 0 else x)
test['paint'] = test['paint'] = test['paint'].apply(lambda x : 'grey' if x.find('gery') >= 0 else x)
test['paint'] = test['paint'] = test['paint'].apply(lambda x : 'grey' if x.find('gray') >= 0 else x)
test['paint'] = test['paint'] = test['paint'].apply(lambda x : 'ash' if x.find('ash') >= 0 else x)
test['paint'] = test['paint'] = test['paint'].apply(lambda x : 'brown' if x.find('brown') >= 0 else x)
test['paint'] = test['paint'] = test['paint'].apply(lambda x : 'silver' if x.find('silver') >= 0 else x)
test['paint'] = test['paint'] = test['paint'].apply(lambda x : 'silver' if x.find('sliver') >= 0 else x)
test['paint'] = test['paint'] = test['paint'].apply(lambda x : 'black' if x.find('black') >= 0 else x)
test['paint'] = test['paint'] = test['paint'].apply(lambda x : 'gold' if x.find('gold') >= 0 else x)
test['paint'] = test['paint'] = test['paint'].apply(lambda x : 'wine' if x.find('whine') >= 0 else x)

# %%
print('test data에서 paint의 unique 카테고리 개수 : ', len(test['paint'].value_counts()))
# Out:
# test data에서 paint의 unique 카테고리 개수 :  18

# %%
sorted(test.paint.unique())
# Out:
# ['ash',
#  'beige',
#  'blac',
#  'black',
#  'blue',
#  'brown',
#  'cream',
#  'gold',
#  'golf',
#  'green',
#  'grey',
#  'indigo ink pearl',
#  'maroon',
#  'red',
#  'silver',
#  'white',
#  'wine',
#  'yellow']

# %%
test['paint'] = test['paint'] = test['paint'].apply(lambda x : 'gold' if x.find('golf') == 0 else x)
test['paint'] = test['paint'] = test['paint'].apply(lambda x : 'black' if x.find('blac') == 0 else x)

# %%
sorted(test.paint.unique())
# Out:
# ['ash',
#  'beige',
#  'black',
#  'blue',
#  'brown',
#  'cream',
#  'gold',
#  'green',
#  'grey',
#  'indigo ink pearl',
#  'maroon',
#  'red',
#  'silver',
#  'white',
#  'wine',
#  'yellow']

# %%
train = train.replace({
    'milk' : 'cream',
    'maroon' : 'red',
    'wine' : 'red',
})

test = test.replace({
    'indigo ink pearl' : 'blue',
    'golf' : 'green',
    'maroon' : 'red',
    'wine' : 'red',
})

# %%
print('train data에서 paint의 unique 카테고리 개수 : ', len(train['paint'].value_counts()))
print('test data에서 paint의 unique 카테고리 개수 : ', len(test['paint'].value_counts()))
# Out:
# train data에서 paint의 unique 카테고리 개수 :  14
# test data에서 paint의 unique 카테고리 개수 :  13

# %%
sorted(train.paint.unique())
# Out:
# ['ash',
#  'beige',
#  'black',
#  'blue',
#  'brown',
#  'cream',
#  'gold',
#  'green',
#  'grey',
#  'purple',
#  'red',
#  'silver',
#  'white',
#  'yellow']

# %%
#무채색 유채색 colum 만들기
train['colorType'] = train['paint'].apply(lambda x:'chromatic' if x=='red' or x=='blue' or x=='brown' or x=='gold' or x=='green' or x=='orange' or x=='purple' or x=='yellow' else 'achromatic') #유채색 chromatic
test['colorType'] = test['paint'].apply(lambda x:'chromatic' if x=='red' or x=='blue' or x=='brown' or x=='gold' or x=='green' or x=='orange' or x=='purple' or x=='yellow' else 'achromatic') #유채색 chromatic

# %%
train.head()
# Out:
#    id                          title  odometer location    isimported  engine  \
# 0   0                   Toyota RAV 4     18277   Lagos   Foreign Used      40
# 1   1            Toyota Land Cruiser        10    Lagos          New       40
# 2   2  Land Rover Range Rover Evoque     83091    Lagos  Foreign Used      50
# 3   3                   Lexus ES 350     91524    Lagos  Foreign Used      40
# 4   4                   Toyota Venza     94177    Lagos  Foreign Used      50
#
#   transmission    fuel  paint  year    target  brand   colorType
# 0    automatic  petrol    red  2016  13665000    220   chromatic
# 1    automatic  petrol  black  2019  33015000    220  achromatic
# 2    automatic  petrol    red  2012   9915000    370   chromatic
# 3    automatic  petrol   grey  2007   3815000    320  achromatic
# 4    automatic  petrol    red  2010   7385000    220   chromatic

# %%
#가격 이상치 변경
train[(train.target > 100000000)]
# Out:
#       id                         title  odometer location    isimported  \
# 323  341  Land Rover Range Rover Sport     18720    Lagos  Foreign Used
# 547  568                  Lexus LX 570     55530    Abuja  Foreign Used
# 575  596             Rolls-Royce Ghost     16069    Lagos  Locally used
# 705  735        Mercedes-Benz G 63 AMG        20    Lagos          New
#
#      engine transmission    fuel  paint  year     target  brand   colorType
# 323      70    automatic  petrol   grey  2019  117015000    370  achromatic
# 547      70    automatic  petrol  black  2014  110015000    320  achromatic
# 575      40    automatic  petrol  black  2011  150015008    380  achromatic
# 705      70    automatic  petrol  black  2019  108690000    310  achromatic

# %%
train.loc[323,'target'] = 33015000
train.loc[547,'target'] = 29015000
train.loc[705,'target'] = 60015000

# %%
#location 값 정리(test,train 둘다 적용)
#location 칼럼 살펴보기
sorted(train.location.unique())
# Out:
# ['Abia',
#  'Abia State',
#  'Abuja',
#  'Abuja ',
#  'Accra',
#  'Adamawa ',
#  'FCT',
#  'Lagos',
#  'Lagos ',
#  'Lagos State',
#  'Ogun',
#  'Ogun State',
#  'other']

# %%
sorted(test.location.unique())
# Out:
# ['Abia',
#  'Abuja',
#  'Abuja ',
#  'Arepo ogun state ',
#  'Lagos',
#  'Lagos ',
#  'Lagos State',
#  'Mushin',
#  'Ogun',
#  'Ogun State',
#  'other']

# %%
#location 값 정제
train = train.replace({
    'Abia State' : 'Abia',
    'Abuja ' : 'Abuja',
    'Lagos ' : 'Lagos',
    'Lagos State' : 'Lagos',
    'Ogun State' : 'Ogun'
    })
test = test.replace({
    'Abuja ' : 'Abuja',
    'Lagos ' : 'Lagos',
    'Lagos State' : 'Lagos',
    'Ogun State' : 'Ogun',
    'Arepo ogun state ' : 'Ogun',
    'Mushin' : 'Lagos'
})

# %%
sorted(train.location.unique())
# Out:
# ['Abia', 'Abuja', 'Accra', 'Adamawa ', 'FCT', 'Lagos', 'Ogun', 'other']

# %%
sorted(test.location.unique())
# Out:
# ['Abia', 'Abuja', 'Lagos', 'Ogun', 'other']

# %%
train.head()
# Out:
#    id                          title  odometer location    isimported  engine  \
# 0   0                   Toyota RAV 4     18277    Lagos  Foreign Used      40
# 1   1            Toyota Land Cruiser        10    Lagos          New       40
# 2   2  Land Rover Range Rover Evoque     83091    Lagos  Foreign Used      50
# 3   3                   Lexus ES 350     91524    Lagos  Foreign Used      40
# 4   4                   Toyota Venza     94177    Lagos  Foreign Used      50
#
#   transmission    fuel  paint  year    target  brand   colorType
# 0    automatic  petrol    red  2016  13665000    220   chromatic
# 1    automatic  petrol  black  2019  33015000    220  achromatic
# 2    automatic  petrol    red  2012   9915000    370   chromatic
# 3    automatic  petrol   grey  2007   3815000    320  achromatic
# 4    automatic  petrol    red  2010   7385000    220   chromatic

# %%
train_title10 = train[train['title'].apply(lambda x : x in train['title'].value_counts()[:10].keys())]
train_brand10 = train[train['brand'].apply(lambda x : x in train['brand'].value_counts()[:10].keys())]

# %%
# feature들의 분포 확인 -> 몇몇 feature가 편향돼있는것을 확인할 수 있음.
# 이는 학습성능에 영향을 미칠것이라고 판단하여 편향 정도가 심한 피처 3가지(fuel,isimported,transmission)를 골라서 stratified k -fold에서 split 기준으로 
#사용하기로 하였다. 피처 3가지의 조합을 기준으로 삼기위해 라벨인코딩을 다음과 같이 진행하였다. (3가지의 조합->18가지)

plt.style.use("ggplot")

plt.figure(figsize=(25,15))
plt.subplot(4,2,1)
sns.countplot(data=train, x='title')
plt.subplot(4,2,2)
sns.countplot(data=train, x='brand')
count = 3

for i in train.describe(include="object").columns.drop(['title'])[:-1]:
    plt.subplot(4,2,count)
    sns.countplot(data=train, x=i)
    count += 1

# %%
#라벨 인코딩

train_en = train.copy()
test_en = test.copy()

# %%
train_en.head()
# Out:
#    id                          title  odometer location    isimported  engine  \
# 0   0                   Toyota RAV 4     18277    Lagos  Foreign Used      40
# 1   1            Toyota Land Cruiser        10    Lagos          New       40
# 2   2  Land Rover Range Rover Evoque     83091    Lagos  Foreign Used      50
# 3   3                   Lexus ES 350     91524    Lagos  Foreign Used      40
# 4   4                   Toyota Venza     94177    Lagos  Foreign Used      50
#
#   transmission    fuel  paint  year    target  brand   colorType
# 0    automatic  petrol    red  2016  13665000    220   chromatic
# 1    automatic  petrol  black  2019  33015000    220  achromatic
# 2    automatic  petrol    red  2012   9915000    370   chromatic
# 3    automatic  petrol   grey  2007   3815000    320  achromatic
# 4    automatic  petrol    red  2010   7385000    220   chromatic

# %%
# 라벨 인코딩(title)
# train, test 데이터에 있는 모든 car title 합치기
car_title = pd.concat([train.title, test.title], ignore_index = True)
car_title = set(car_title)
car_title
# Out:
# {'ALPINA B3',
#  'Acura MDX',
#  'Acura RDX',
#  'Acura TL',
#  'Acura TSX',
#  'Acura ZDX',
#  'BMW 325',
#  'BMW 335',
#  'BMW 525',
#  'BMW 528',
#  'BMW 535',
#  'BMW 730',
#  'BMW 740',
#  'BMW 745',
#  'BMW 750',
#  'BMW X3',
#  'BMW X6',
#  'Bentley Arnage',
#  'Chevrolet Camaro',
#  'Chevrolet Evanda',
#  'Chevrolet Traverse',
#  'DAF 95XF TRACTOR HEAD',
#  'DAF CF',
#  'DAF XF TRACTOR HEAD',
#  'Fiat Ducato',
#  'Ford Edge',
#  'Ford Escape',
#  'Ford Expedition',
#  'Ford Explorer',
#  'Ford F 150',
#  'Ford Focus',
#  'Ford Fusion',
#  'Ford Mondeo',
#  'Ford Mustang',
#  'Ford TRANSIT PICKUP',
#  'Ford Transit',
#  'GAC Gonow Other',
#  'GMC Terrain',
#  'Honda Accord',
#  'Honda CR-V',
#  'Honda Civic',
#  'Honda Crosstour',
#  'Honda Element',
#  'Honda Fit',
#  'Honda Insight',
#  'Honda Odyssey',
#  'Honda Pilot',
#  'Honda Ridgeline',
#  'Hyundai Azera',
#  'Hyundai Elantra',
#  'Hyundai Santa Fe',
#  'Hyundai Sonata',
#  'Hyundai Tucson',
#  'Hyundai ix35',
#  'IVECO EUROTECH 7.50E-16',
#  'IVM LT35',
#  'Infiniti FX',
#  'Infiniti JX',
#  'Infiniti M35',
#  'Infiniti QX80',
#  'Isuzu CABSTER',
#  'Isuzu NQR',
#  'Iveco EUROCARGO 120e18',
#  'Iveco TRUCK',
#  'JMC Vigus',
#  'Jaguar X-Type',
#  'Jaguar XJ8',
#  'Jeep Cherokee',
#  'Jeep Wrangler',
#  'Kia Cerato',
#  'Kia Optima',
#  'Kia Picanto',
#  'Kia Rio',
#  'Kia Sorento',
#  'Kia Stinger',
#  'Land Rover Discovery',
#  'Land Rover Range Rover',
#  'Land Rover Range Rover Evoque',
#  'Land Rover Range Rover Sport',
#  'Land Rover Range Rover Velar',
#  'Lexus CT 200h',
#  'Lexus ES 300',
#  'Lexus ES 330',
#  'Lexus ES 350',
#  'Lexus GS 300',
#  'Lexus GS 350',
#  'Lexus GX 460',
#  'Lexus GX 470',
#  'Lexus IS 250',
#  'Lexus LS 460',
#  'Lexus LX 570',
#  'Lexus RX 300',
#  'Lexus RX 330',
#  'Lexus RX 350',
#  'Lexus RX 400',
#  'Lincoln Mark',
#  'MAN-VOLKSWAGEN FLATBED',
#  'MINI Cooper',
#  'MINI Cooper Countryman',
#  'MINI Cooper Coupé',
#  'Mack CH613',
#  'Mack CXN613 CAB BEHIND ENGINE',
#  'Mack R-686ST',
#  'Man 26-403',
#  'Man BOCKMANN',
#  'Man LE 8. 180 PLATFORM TRUCK',
#  'Man TGA 18.360',
#  'Man Truck 18.44',
#  'Mazda 323',
#  'Mazda 6',
#  'Mazda CX-9',
#  'Mazda Tribute',
#  'Mercedes-Benz 200',
#  'Mercedes-Benz 220',
#  'Mercedes-Benz 300',
#  'Mercedes-Benz 320',
#  'Mercedes-Benz 350',
#  'Mercedes-Benz 450',
#  'Mercedes-Benz 814',
#  'Mercedes-Benz C 180',
#  'Mercedes-Benz C 250',
#  'Mercedes-Benz C 300',
#  'Mercedes-Benz C 320',
#  'Mercedes-Benz C 350',
#  'Mercedes-Benz C 450 AMG',
#  'Mercedes-Benz C 63 AMG',
#  'Mercedes-Benz CABIN PLUS CHASSIS ONLY',
#  'Mercedes-Benz CLA 250',
#  'Mercedes-Benz CLS 500',
#  'Mercedes-Benz DUMP TRUCK',
#  'Mercedes-Benz E 200',
#  'Mercedes-Benz E 300',
#  'Mercedes-Benz E 320',
#  'Mercedes-Benz E 350',
#  'Mercedes-Benz E 550',
#  'Mercedes-Benz G 550',
#  'Mercedes-Benz G 63 AMG',
#  'Mercedes-Benz GL 450',
#  'Mercedes-Benz GLA 180',
#  'Mercedes-Benz GLA 250',
#  'Mercedes-Benz GLC 300',
#  'Mercedes-Benz GLE 350',
#  'Mercedes-Benz GLE 43 AMG',
#  'Mercedes-Benz GLE 450',
#  'Mercedes-Benz GLK 300',
#  'Mercedes-Benz GLK 350',
#  'Mercedes-Benz ML 320',
#  'Mercedes-Benz ML 350',
#  'Mercedes-Benz ML 430',
#  'Mercedes-Benz Maybach',
#  'Mercedes-Benz S 450',
#  'Mercedes-Benz S 550',
#  'Mercedes-Benz SL 400',
#  'Mercedes-Benz WATER TANKER',
#  'Mitsubishi CANTER PICK UP',
#  'Mitsubishi Eclipse',
#  'Mitsubishi Galant',
#  'Mitsubishi L200',
#  'Mitsubishi Montero',
#  'Mitsubishi Pajero',
#  'Nissan A',
#  'Nissan Altima',
#  'Nissan Cabstar',
#  'Nissan Frontier',
#  'Nissan INFINITI M90.150/2',
#  'Nissan Maxima',
#  'Nissan Murano',
#  'Nissan Pathfinder',
#  'Nissan Primera',
#  'Nissan Quest',
#  'Nissan Rogue',
#  'Nissan Sentra',
#  'Nissan Titan',
#  'Nissan Versa',
#  'Nissan Xterra',
#  'Peugeot 206',
#  'Peugeot 307',
#  'Peugeot 308',
#  'Peugeot 607',
#  'Pontiac Vibe',
#  'Porsche Cayenne',
#  'Porsche Macan',
#  'Porsche Panamera',
#  'Rolls-Royce Ghost',
#  'Scania P94 FLATBED',
#  'Scania TRACTOR HEAD',
#  'Toyota 4-Runner',
#  'Toyota Avalon',
#  'Toyota Avensis',
#  'Toyota C-HR',
#  'Toyota Camry',
#  'Toyota Coaster',
#  'Toyota Corolla',
#  'Toyota DYNA 200',
#  'Toyota Dyna',
#  'Toyota Hiace',
#  'Toyota Highlander',
#  'Toyota Hilux',
#  'Toyota Land Cruiser',
#  'Toyota Matrix',
#  'Toyota Prado',
#  'Toyota Prius',
#  'Toyota RAV 4',
#  'Toyota Sequoia',
#  'Toyota Sienna',
#  'Toyota Solara',
#  'Toyota Tacoma',
#  'Toyota Tundra',
#  'Toyota Venza',
#  'Toyota Vitz',
#  'Toyota Yaris',
#  'Volkswagen 17.22',
#  'Volkswagen Golf',
#  'Volkswagen Jetta',
#  'Volkswagen Passat',
#  'Volkswagen Sharan',
#  'Volkswagen T4 Caravelle',
#  'Volkswagen T6 other',
#  'Volkswagen Tiguan',
#  'Volkswagen Touareg',
#  'Volvo FH12',
#  'Volvo FL12',
#  'Volvo FL6',
#  'Volvo FL7',
#  'Volvo S80',
#  'Volvo XC60',
#  'Volvo XC90'}

# %%
# label 생성을 위한 dictionary 생성
car_title_label = {car_title : label for label, car_title in enumerate(car_title)}
car_title_label
# Out:
# {'Mitsubishi Galant': 0,
#  'Mazda Tribute': 1,
#  'Mercedes-Benz ML 320': 2,
#  'Toyota Tacoma': 3,
#  'Mercedes-Benz S 450': 4,
#  'Nissan Frontier': 5,
#  'Mercedes-Benz 350': 6,
#  'Porsche Macan': 7,
#  'Man 26-403': 8,
#  'Lexus RX 400': 9,
#  'Toyota Corolla': 10,
#  'Nissan Sentra': 11,
#  'Infiniti M35': 12,
#  'Toyota Sequoia': 13,
#  'Chevrolet Traverse': 14,
#  'DAF 95XF TRACTOR HEAD': 15,
#  'Honda Insight': 16,
#  'Volkswagen 17.22': 17,
#  'Mitsubishi Montero': 18,
#  'Lexus LX 570': 19,
#  'BMW 528': 20,
#  'Mercedes-Benz C 450 AMG': 21,
#  'Mazda 323': 22,
#  'Toyota Sienna': 23,
#  'Toyota Solara': 24,
#  'Mercedes-Benz E 200': 25,
#  'Nissan Rogue': 26,
#  'Mercedes-Benz 200': 27,
#  'Rolls-Royce Ghost': 28,
#  'ALPINA B3': 29,
#  'Nissan Altima': 30,
#  'BMW 730': 31,
#  'BMW 535': 32,
#  'Infiniti FX': 33,
#  'Mazda 6': 34,
#  'BMW 750': 35,
#  'Honda Civic': 36,
#  'Toyota Camry': 37,
#  'Volkswagen T6 other': 38,
#  'Honda Fit': 39,
#  'Honda Crosstour': 40,
#  'Scania TRACTOR HEAD': 41,
#  'Honda Odyssey': 42,
#  'Man LE 8. 180 PLATFORM TRUCK': 43,
#  'Toyota Prado': 44,
#  'Honda Element': 45,
#  'Mitsubishi CANTER PICK UP': 46,
#  'Nissan Murano': 47,
#  'Ford Transit': 48,
#  'BMW 325': 49,
#  'IVECO EUROTECH 7.50E-16': 50,
#  'Lexus ES 350': 51,
#  'Mercedes-Benz C 300': 52,
#  'Nissan Titan': 53,
#  'Mercedes-Benz C 180': 54,
#  'Mitsubishi Eclipse': 55,
#  'Mercedes-Benz CLA 250': 56,
#  'Mercedes-Benz ML 430': 57,
#  'Ford F 150': 58,
#  'Toyota Venza': 59,
#  'Lexus LS 460': 60,
#  'Mercedes-Benz E 550': 61,
#  'JMC Vigus': 62,
#  'Mercedes-Benz 814': 63,
#  'Mack CH613': 64,
#  'DAF XF TRACTOR HEAD': 65,
#  'Ford Mustang': 66,
#  'Infiniti QX80': 67,
#  'Mercedes-Benz Maybach': 68,
#  'Mercedes-Benz GLC 300': 69,
#  'Toyota Vitz': 70,
#  'Iveco TRUCK': 71,
#  'Mercedes-Benz SL 400': 72,
#  'Toyota RAV 4': 73,
#  'Infiniti JX': 74,
#  'Volkswagen Tiguan': 75,
#  'Mercedes-Benz E 350': 76,
#  'Honda Accord': 77,
#  'Mercedes-Benz GLE 43 AMG': 78,
#  'Porsche Cayenne': 79,
#  'Land Rover Range Rover Sport': 80,
#  'Jeep Wrangler': 81,
#  'Volvo S80': 82,
#  'GMC Terrain': 83,
#  'Mercedes-Benz 220': 84,
#  'Mitsubishi L200': 85,
#  'Mercedes-Benz WATER TANKER': 86,
#  'Isuzu CABSTER': 87,
#  'Nissan INFINITI M90.150/2': 88,
#  'Mercedes-Benz GLK 350': 89,
#  'Jaguar XJ8': 90,
#  'Lexus GX 460': 91,
#  'Mercedes-Benz GLA 180': 92,
#  'Toyota DYNA 200': 93,
#  'Hyundai Santa Fe': 94,
#  'Mercedes-Benz C 250': 95,
#  'Mercedes-Benz C 63 AMG': 96,
#  'Mercedes-Benz G 550': 97,
#  'Toyota Tundra': 98,
#  'Acura TL': 99,
#  'Hyundai Elantra': 100,
#  'DAF CF': 101,
#  'Toyota 4-Runner': 102,
#  'Hyundai Azera': 103,
#  'Volkswagen Jetta': 104,
#  'Toyota Coaster': 105,
#  'Kia Stinger': 106,
#  'Lexus ES 300': 107,
#  'Mercedes-Benz G 63 AMG': 108,
#  'Mercedes-Benz C 320': 109,
#  'Ford TRANSIT PICKUP': 110,
#  'Honda Pilot': 111,
#  'Lexus GX 470': 112,
#  'Nissan Maxima': 113,
#  'Mack R-686ST': 114,
#  'Ford Explorer': 115,
#  'Scania P94 FLATBED': 116,
#  'Hyundai ix35': 117,
#  'BMW 525': 118,
#  'Lincoln Mark': 119,
#  'Volvo FL12': 120,
#  'Land Rover Range Rover Velar': 121,
#  'Mercedes-Benz GL 450': 122,
#  'Lexus RX 350': 123,
#  'Land Rover Range Rover': 124,
#  'Hyundai Tucson': 125,
#  'MINI Cooper Countryman': 126,
#  'Volvo FL7': 127,
#  'Mercedes-Benz GLK 300': 128,
#  'Hyundai Sonata': 129,
#  'BMW X6': 130,
#  'Toyota Hilux': 131,
#  'Volkswagen Passat': 132,
#  'Honda CR-V': 133,
#  'Ford Fusion': 134,
#  'Bentley Arnage': 135,
#  'Toyota Highlander': 136,
#  'Toyota Dyna': 137,
#  'Isuzu NQR': 138,
#  'Jaguar X-Type': 139,
#  'Toyota Avalon': 140,
#  'Mack CXN613 CAB BEHIND ENGINE': 141,
#  'Ford Edge': 142,
#  'Volvo XC90': 143,
#  'Mercedes-Benz DUMP TRUCK': 144,
#  'Volkswagen Golf': 145,
#  'Kia Rio': 146,
#  'Nissan Cabstar': 147,
#  'Mazda CX-9': 148,
#  'Volvo FL6': 149,
#  'MAN-VOLKSWAGEN FLATBED': 150,
#  'Peugeot 607': 151,
#  'Acura TSX': 152,
#  'Mercedes-Benz ML 350': 153,
#  'BMW X3': 154,
#  'Mercedes-Benz GLA 250': 155,
#  'BMW 745': 156,
#  'Mercedes-Benz C 350': 157,
#  'Volkswagen Sharan': 158,
#  'Mercedes-Benz 300': 159,
#  'Acura ZDX': 160,
#  'Man TGA 18.360': 161,
#  'Mercedes-Benz S 550': 162,
#  'Mercedes-Benz 320': 163,
#  'Nissan Xterra': 164,
#  'Kia Optima': 165,
#  'Nissan A': 166,
#  'Mercedes-Benz E 320': 167,
#  'Kia Cerato': 168,
#  'Iveco EUROCARGO 120e18': 169,
#  'Acura RDX': 170,
#  'Lexus GS 300': 171,
#  'Mercedes-Benz CABIN PLUS CHASSIS ONLY': 172,
#  'Nissan Versa': 173,
#  'Lexus CT 200h': 174,
#  'Volvo XC60': 175,
#  'Toyota Yaris': 176,
#  'Toyota Land Cruiser': 177,
#  'Ford Expedition': 178,
#  'BMW 335': 179,
#  'Mercedes-Benz GLE 350': 180,
#  'Pontiac Vibe': 181,
#  'Kia Sorento': 182,
#  'Lexus RX 330': 183,
#  'Mercedes-Benz 450': 184,
#  'Peugeot 307': 185,
#  'Land Rover Range Rover Evoque': 186,
#  'Volkswagen T4 Caravelle': 187,
#  'Nissan Pathfinder': 188,
#  'Toyota C-HR': 189,
#  'Man Truck 18.44': 190,
#  'Fiat Ducato': 191,
#  'GAC Gonow Other': 192,
#  'IVM LT35': 193,
#  'Peugeot 308': 194,
#  'Ford Mondeo': 195,
#  'Man BOCKMANN': 196,
#  'Mercedes-Benz GLE 450': 197,
#  'MINI Cooper Coupé': 198,
#  'Ford Focus': 199,
#  'Toyota Matrix': 200,
#  'Lexus ES 330': 201,
#  'Ford Escape': 202,
#  'BMW 740': 203,
#  'Nissan Quest': 204,
#  'Mitsubishi Pajero': 205,
#  'Kia Picanto': 206,
#  'Peugeot 206': 207,
#  'Toyota Prius': 208,
#  'MINI Cooper': 209,
#  'Volvo FH12': 210,
#  'Volkswagen Touareg': 211,
#  'Lexus RX 300': 212,
#  'Lexus IS 250': 213,
#  'Acura MDX': 214,
#  'Chevrolet Evanda': 215,
#  'Jeep Cherokee': 216,
#  'Mercedes-Benz E 300': 217,
#  'Land Rover Discovery': 218,
#  'Honda Ridgeline': 219,
#  'Toyota Hiace': 220,
#  'Toyota Avensis': 221,
#  'Porsche Panamera': 222,
#  'Nissan Primera': 223,
#  'Mercedes-Benz CLS 500': 224,
#  'Chevrolet Camaro': 225,
#  'Lexus GS 350': 226}

# %%
# 생성된 dictionary를 이용하여 car title labeling
train_en['title'] = train['title'].replace(car_title_label)
test_en['title'] = test['title'].replace(car_title_label)

# %%
# 라벨 인코딩(location)
train.location.unique()
# Out:
# array(['Lagos', 'Abuja', 'Ogun', 'FCT', 'Accra', 'other', 'Abia',
#        'Adamawa '], dtype=object)

# %%
test.location.unique()
# Out:
# array(['Abuja', 'Lagos', 'Ogun', 'other', 'Abia'], dtype=object)

# %%
#train data와 test data에 공통적으로 존재하는 값을 제외하고 other로 통합하기
# 합집합( '|' ) - 교집합( '&' )
set(set(train.location.unique()) | set(test.location.unique())) - set(set(train.location.unique()) & set(test.location.unique()))
# Out:
# {'Accra', 'Adamawa ', 'FCT'}

# %%
train['location'] = train['location'].replace({
    'Accra' : 'other',
    'Adamawa ' : 'other',
    'FCT' : 'other',
    'Mushin' : 'other'
})

train.location.unique()
# Out:
# array(['Lagos', 'Abuja', 'Ogun', 'other', 'Abia'], dtype=object)

# %%
test['location'] = test['location'].replace({
    'Accra' : 'other',
    'Adamawa ' : 'other',
    'FCT' : 'other',
    'Mushin' : 'other'
})

test.location.unique()
# Out:
# array(['Abuja', 'Lagos', 'Ogun', 'other', 'Abia'], dtype=object)

# %%
location_label = {location : label for label, location in enumerate(train.location.unique())}
location_label
# Out:
# {'Lagos': 0, 'Abuja': 1, 'Ogun': 2, 'other': 3, 'Abia': 4}

# %%
train_en['location'] = train['location'].replace(location_label)
test_en['location'] = test['location'].replace(location_label)

# %%
# 라벨 인코딩(paint)
train.paint.unique()
# Out:
# array(['red', 'black', 'grey', 'white', 'blue', 'silver', 'brown',
#        'green', 'purple', 'gold', 'cream', 'beige', 'ash', 'yellow'],
#       dtype=object)

# %%
test.paint.unique()
# Out:
# array(['white', 'black', 'grey', 'red', 'silver', 'blue', 'gold', 'green',
#        'cream', 'brown', 'yellow', 'ash', 'beige'], dtype=object)

# %%
paint_label = {_paint : label for label, _paint in enumerate(set(pd.concat([train.paint, test.paint])))}
paint_label
# Out:
# {'black': 0,
#  'blue': 1,
#  'ash': 2,
#  'gold': 3,
#  'white': 4,
#  'brown': 5,
#  'grey': 6,
#  'green': 7,
#  'cream': 8,
#  'purple': 9,
#  'red': 10,
#  'yellow': 11,
#  'silver': 12,
#  'beige': 13}

# %%
train_en['paint'] = train['paint'].replace(paint_label)
test_en['paint'] = test['paint'].replace(paint_label)

# %%
test_en.head()
# Out:
#    id  title  odometer  location    isimported  engine transmission    fuel  \
# 0   0     52      1234         1          New       40    automatic  petrol
# 1   1     77     29938         1  Foreign Used      40    automatic  petrol
# 2   2    162     87501         0  Foreign Used      40    automatic  petrol
# 3   3     23    180894         0  Locally used      50    automatic  petrol
# 4   4    220    104814         0  Foreign Used      40    automatic  petrol
#
#    paint  year  brand   colorType
# 0      4  2017    310  achromatic
# 1      4  2013    150  achromatic
# 2      0  2012    310  achromatic
# 3      6  2001    220  achromatic
# 4      4  2000    220  achromatic

# %%
#비정상적인 year column의 변수 변경
test[(test.year == 1324) | (test.year == 1726) | (test.year == 2626)]
# Out:
#       id                                  title  odometer location  \
# 304  304  Mercedes-Benz CABIN PLUS CHASSIS ONLY    650923    Lagos
# 406  406               Mercedes-Benz DUMP TRUCK         0    Lagos
# 411  411             Mercedes-Benz WATER TANKER    701934    Lagos
#
#        isimported  engine transmission    fuel  paint  year  brand   colorType
# 304  Locally used      50       manual  diesel   blue  1324    310   chromatic
# 406  Locally used      70       manual  diesel  white  2626    310  achromatic
# 411  Locally used      70       manual  diesel  white  1726    310  achromatic

# %%
test_en['year'] = test_en['year'].replace([1324, 1726, 2626], [2010, 2010, 2020])

# %%
test_en.iloc[[304, 406, 411]]
# Out:
#       id  title  odometer  location    isimported  engine transmission  \
# 304  304    172    650923         0  Locally used      50       manual
# 406  406    144         0         0  Locally used      70       manual
# 411  411     86    701934         0  Locally used      70       manual
#
#        fuel  paint  year  brand   colorType
# 304  diesel      1  2010    310   chromatic
# 406  diesel      4  2020    310  achromatic
# 411  diesel      4  2010    310  achromatic

# %%
#편향된 피처들의 조합으로 stratified k fold 하기 위해 
isimported_label = {'Foreign Used': 100, 'Locally used' : 200, 'New ' : 300}
transmission_label = {'automatic' : 10, 'manual' : 20}
fuel_label = {'petrol' : 1, 'diesel' : 2}

# %%
train_en['isimported'] = train_en['isimported'].replace(isimported_label)
test_en['isimported'] = test_en['isimported'].replace(isimported_label)

train_en['transmission'] = train_en['transmission'].replace(transmission_label)
test_en['transmission'] = test_en['transmission'].replace(transmission_label)

train_en['fuel'] = train_en['fuel'].replace(fuel_label)
test_en['fuel'] = test_en['fuel'].replace(fuel_label)

# %%
train_en.head()
# Out:
#    id  title  odometer  location  isimported  engine  transmission  fuel  \
# 0   0     73     18277         0         100      40            10     1
# 1   1    177        10         0         300      40            10     1
# 2   2    186     83091         0         100      50            10     1
# 3   3     51     91524         0         100      40            10     1
# 4   4     59     94177         0         100      50            10     1
#
#    paint  year    target  brand   colorType
# 0     10  2016  13665000    220   chromatic
# 1      0  2019  33015000    220  achromatic
# 2     10  2012   9915000    370   chromatic
# 3      6  2007   3815000    320  achromatic
# 4     10  2010   7385000    220   chromatic

# %%
test_en.head()
# Out:
#    id  title  odometer  location  isimported  engine  transmission  fuel  \
# 0   0     52      1234         1         300      40            10     1
# 1   1     77     29938         1         100      40            10     1
# 2   2    162     87501         0         100      40            10     1
# 3   3     23    180894         0         200      50            10     1
# 4   4    220    104814         0         100      40            10     1
#
#    paint  year  brand   colorType
# 0      4  2017    310  achromatic
# 1      4  2013    150  achromatic
# 2      0  2012    310  achromatic
# 3      6  2001    220  achromatic
# 4      4  2000    220  achromatic

# %%
# 라벨 인코딩(colorType)
color_type_label = {'achromatic' : 0, 'chromatic' : 1}

# %%
train_en['colorType'] = train_en['colorType'].replace(color_type_label)
test_en['colorType'] = test_en['colorType'].replace(color_type_label)

# %%
train_en.head()
# Out:
#    id  title  odometer  location  isimported  engine  transmission  fuel  \
# 0   0     73     18277         0         100      40            10     1
# 1   1    177        10         0         300      40            10     1
# 2   2    186     83091         0         100      50            10     1
# 3   3     51     91524         0         100      40            10     1
# 4   4     59     94177         0         100      50            10     1
#
#    paint  year    target  brand  colorType
# 0     10  2016  13665000    220          1
# 1      0  2019  33015000    220          0
# 2     10  2012   9915000    370          1
# 3      6  2007   3815000    320          0
# 4     10  2010   7385000    220          1

# %%
#stratified-k-fold의 split 기준으로 사용할 칼럼 생성
feature_sum = train_en['transmission']+train_en['fuel']+train_en['isimported']

# %%
train_en["sum"] = feature_sum
train_en.head()
# Out:
#    id  title  odometer  location  isimported  engine  transmission  fuel  \
# 0   0     73     18277         0         100      40            10     1
# 1   1    177        10         0         300      40            10     1
# 2   2    186     83091         0         100      50            10     1
# 3   3     51     91524         0         100      40            10     1
# 4   4     59     94177         0         100      50            10     1
#
#    paint  year    target  brand  colorType  sum
# 0     10  2016  13665000    220          1  111
# 1      0  2019  33015000    220          0  311
# 2     10  2012   9915000    370          1  111
# 3      6  2007   3815000    320          0  111
# 4     10  2010   7385000    220          1  111

# %%
test_en.head()
# Out:
#    id  title  odometer  location  isimported  engine  transmission  fuel  \
# 0   0     52      1234         1         300      40            10     1
# 1   1     77     29938         1         100      40            10     1
# 2   2    162     87501         0         100      40            10     1
# 3   3     23    180894         0         200      50            10     1
# 4   4    220    104814         0         100      40            10     1
#
#    paint  year  brand  colorType
# 0      4  2017    310          0
# 1      4  2013    150          0
# 2      0  2012    310          0
# 3      6  2001    220          0
# 4      4  2000    220          0

# %%
#target값 log 변경
log_df = train_en.copy()
log_df['target'] = np.log(log_df['target'])
log_df.head()
# Out:
#    id  title  odometer  location  isimported  engine  transmission  fuel  \
# 0   0     73     18277         0         100      40            10     1
# 1   1    177        10         0         300      40            10     1
# 2   2    186     83091         0         100      50            10     1
# 3   3     51     91524         0         100      40            10     1
# 4   4     59     94177         0         100      50            10     1
#
#    paint  year     target  brand  colorType  sum
# 0     10  2016  16.430348    220          1  111
# 1      0  2019  17.312473    220          0  311
# 2     10  2012  16.109559    370          1  111
# 3      6  2007  15.154451    320          0  111
# 4     10  2010  15.814961    220          1  111

# %%
data_train_X = log_df.drop(columns = ['target','id'],axis = 1)
data_train_X.head()
# Out:
#    title  odometer  location  isimported  engine  transmission  fuel  paint  \
# 0     73     18277         0         100      40            10     1     10
# 1    177        10         0         300      40            10     1      0
# 2    186     83091         0         100      50            10     1     10
# 3     51     91524         0         100      40            10     1      6
# 4     59     94177         0         100      50            10     1     10
#
#    year  brand  colorType  sum
# 0  2016    220          1  111
# 1  2019    220          0  311
# 2  2012    370          1  111
# 3  2007    320          0  111
# 4  2010    220          1  111

# %%
data_train_y = log_df['target']
data_train_y.head()
# Out:
# 0    16.430348
# 1    17.312473
# 2    16.109559
# 3    15.154451
# 4    15.814961
# Name: target, dtype: float64

# %%
data_test = test_en.copy()

# %%
data_test.head()
# Out:
#    id  title  odometer  location  isimported  engine  transmission  fuel  \
# 0   0     52      1234         1         300      40            10     1
# 1   1     77     29938         1         100      40            10     1
# 2   2    162     87501         0         100      40            10     1
# 3   3     23    180894         0         200      50            10     1
# 4   4    220    104814         0         100      40            10     1
#
#    paint  year  brand  colorType
# 0      4  2017    310          0
# 1      4  2013    150          0
# 2      0  2012    310          0
# 3      6  2001    220          0
# 4      4  2000    220          0

# %%
data_test = data_test.drop(columns = ['id'],axis = 1)
data_test.head()
# Out:
#    title  odometer  location  isimported  engine  transmission  fuel  paint  \
# 0     52      1234         1         300      40            10     1      4
# 1     77     29938         1         100      40            10     1      4
# 2    162     87501         0         100      40            10     1      0
# 3     23    180894         0         200      50            10     1      6
# 4    220    104814         0         100      40            10     1      4
#
#    year  brand  colorType
# 0  2017    310          0
# 1  2013    150          0
# 2  2012    310          0
# 3  2001    220          0
# 4  2000    220          0

# %% [markdown]
# # 하이퍼파라미터 찾기

# %%
#최적화 하이퍼 파라미터 확인을 위한 GreadSearchCV 라이브러리 import

from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor
from catboost import CatBoostRegressor
from sklearn.ensemble import GradientBoostingRegressor

#RandomForestRegressor 모델의 최적 하이퍼 파라미터 확인을 위한 범위 설정
cv_rft = { 
    'n_estimators': [200, 500],
    'max_features': ['auto', 'log2'],
    'max_depth' : [4,5,6,7,8]
}
#범위 안의 하이퍼파라미터들을 조합해 학습
CV_rfc = GridSearchCV(RandomForestRegressor(), param_grid=cv_rft, cv= 5)
CV_rfc.fit(data_train_X, data_train_y)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestRegressor(),
#              param_grid={'max_depth': [4, 5, 6, 7, 8],
#                          'max_features': ['auto', 'log2'],
#                          'n_estimators': [200, 500]})

# %%
#최적 하이퍼 파라미터 확인
print(CV_rfc.best_params_)
# Out:
# {'max_depth': 8, 'max_features': 'auto', 'n_estimators': 500}

# %%
#CatBoostRegressor 모델의 최적 하이퍼 파라미터 확인을 위한 범위 설정
cv_cb = {'depth' : [4,5,6,7,8,9, 10],
         'learning_rate' : [0.01,0.02,0.03,0.04],
         'iterations'    : [10]
}
#범위 안의 하이퍼파라미터들을 조합해 학습
cv_cb = GridSearchCV(CatBoostRegressor(), param_grid=cv_cb, cv=5)
cv_cb.fit(data_train_X, data_train_y)
# Out:
# 0:	learn: 0.9811057	total: 930us	remaining: 8.37ms
# 1:	learn: 0.9750757	total: 1.91ms	remaining: 7.65ms
# 2:	learn: 0.9691488	total: 2.88ms	remaining: 6.71ms
# 3:	learn: 0.9630549	total: 3.88ms	remaining: 5.82ms
# 4:	learn: 0.9574168	total: 4.7ms	remaining: 4.7ms
# 5:	learn: 0.9522699	total: 5.63ms	remaining: 3.75ms
# 6:	learn: 0.9467274	total: 6.57ms	remaining: 2.82ms
# 7:	learn: 0.9410218	total: 7.32ms	remaining: 1.83ms
# 8:	learn: 0.9355720	total: 8.26ms	remaining: 917us
# 9:	learn: 0.9301957	total: 9.14ms	remaining: 0us
# 0:	learn: 0.9638556	total: 618us	remaining: 5.57ms
# 1:	learn: 0.9578946	total: 1.3ms	remaining: 5.21ms
# 2:	learn: 0.9520521	total: 2.08ms	remaining: 4.85ms
# 3:	learn: 0.9460225	total: 2.9ms	remaining: 4.35ms
# 4:	learn: 0.9401871	total: 3.74ms	remaining: 3.74ms
# 5:	learn: 0.9352656	total: 4.82ms	remaining: 3.21ms
# 6:	learn: 0.9295859	total: 5.58ms	remaining: 2.39ms
# 7:	learn: 0.9237968	total: 6.47ms	remaining: 1.62ms
# 8:	learn: 0.9183386	total: 7.35ms	remaining: 816us
# 9:	learn: 0.9129681	total: 8.11ms	remaining: 0us
# 0:	learn: 0.9348706	total: 708us	remaining: 6.37ms
# 1:	learn: 0.9294167	total: 1.41ms	remaining: 5.64ms
# 2:	learn: 0.9238620	total: 2.08ms	remaining: 4.85ms
# 3:	learn: 0.9180833	total: 2.85ms	remaining: 4.27ms
# 4:	learn: 0.9126663	total: 3.63ms	remaining: 3.63ms
# 5:	learn: 0.9079524	total: 4.43ms	remaining: 2.96ms
# 6:	learn: 0.9026838	total: 5.34ms	remaining: 2.29ms
# 7:	learn: 0.8972458	total: 6.19ms	remaining: 1.55ms
# 8:	learn: 0.8921471	total: 7.02ms	remaining: 780us
#              param_grid={'depth': [4, 5, 6, 7, 8, 9, 10], 'iterations': [10],
#                          'learning_rate': [0.01, 0.02, 0.03, 0.04]})

# %%
#최적 하이퍼 파라미터 확인
print(cv_cb.best_params_)
# Out:
# {'depth': 7, 'iterations': 10, 'learning_rate': 0.04}

# %%
#GradientBoostingRegressor 모델의 최적 하이퍼 파라미터 확인을 위한 범위 설정
cv_gbr_params = {
    'learning_rate': [0.01,0.02,0.03,0.04],
    'subsample'    : [0.9, 0.5, 0.2, 0.1],
    'n_estimators' : [100,500],
    'max_depth'    : [4,6,8,10]
}
#범위 안의 하이퍼 파라미터들을 조합해 학습
cv_gbr = GridSearchCV(GradientBoostingRegressor(), param_grid=cv_gbr_params, cv=5)
cv_gbr.fit(data_train_X, data_train_y)
# Out:
# GridSearchCV(cv=5, estimator=GradientBoostingRegressor(),
#              param_grid={'learning_rate': [0.01, 0.02, 0.03, 0.04],
#                          'max_depth': [4, 6, 8, 10], 'n_estimators': [100, 500],
#                          'subsample': [0.9, 0.5, 0.2, 0.1]})

# %%
#최적 하이퍼 파라미터 확인
print(cv_gbr.best_params_)
# Out:
# {'learning_rate': 0.04, 'max_depth': 4, 'n_estimators': 500, 'subsample': 0.9}

# %% [markdown]
# # 모델링

# %%
def NMAE(true, pred):
    score = np.mean(np.abs(true - pred) / true)
    return score

# %%
from sklearn.model_selection import StratifiedKFold

skf = StratifiedKFold(n_splits = 10, random_state = 42, shuffle = True) #총 10번의 fold 진행
n = 0 #x번째 fold인지 기록

fold_target_pred = []

for train_index, valid_index in skf.split(data_train_X, data_train_X['sum']):
    n += 1
    
    val_pred_name = [] #validation pred model 이름 저장
    val_pred = []      #validation set pred 결과 저장
    target_pred = []   #test set pred 결과 저장
    
    train_X = np.array(data_train_X.drop(columns = ['sum'], axis = 1)) #분배된 학습을 위해 만들어둔 sum column 삭제
    train_Y = np.array(data_train_y)
    
    X_train, X_valid = train_X[train_index], train_X[valid_index]
    y_train, y_valid = train_Y[train_index], train_Y[valid_index]
    
    X_test = np.array(data_test)

    #모델생성
    
    #ct
    model = CatBoostRegressor(iterations = 1000, verbose = 0, task_type="CPU", random_state = 42)
    model.fit(X_train, y_train)
    
    val_pred_name.append("catboost")      # 모델 이름 저장
    val_pred.append(model.predict(X_valid))   # validation set pred 결과 저장
    target_pred.append(model.predict(X_test)) # test set pred 결과 저장
    
    #rf
    model = RandomForestRegressor()
    model.fit(X_train, y_train)
    
    val_pred_name.append("rf")      # 모델 이름 저장
    val_pred.append(model.predict(X_valid))   # validation set pred 결과 저장
    target_pred.append(model.predict(X_test)) # test set pred 결과 저장
    
    #gbr
    model = GradientBoostingRegressor(random_state=0)
    model.fit(X_train, y_train)
    
    val_pred_name.append("gbr")      # 모델 이름 저장
    val_pred.append(model.predict(X_valid))   # validation set pred 결과 저장
    target_pred.append(model.predict(X_test)) # test set pred 결과 저장
    
    #soft voting
    
    #average validation pred
    preds = np.array(val_pred[0])
    for i in range(1, len(val_pred)):
        preds += val_pred[i]
    
    preds = preds/len(val_pred)
    
    #average target pred
    target_preds = np.array(target_pred[0])
    for i in range(1, len(target_pred)):
        target_preds += target_pred[i]
    
    target_preds = target_preds/len(target_pred)
    
    fold_target_pred.append(target_preds) #append final target pred
    
    print("*********** fold %d ***********" %(n))
    for i in range(len(val_pred)):
        print("%s model NMAE : %0.4f" %(val_pred_name[i], NMAE(y_valid, val_pred[i].astype(int))))
        
    print("********************************")
    print("Average NMAE %0.4f" %(NMAE(y_valid, preds.astype(int))))
    print("")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:680: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=10.
#   UserWarning,
# *********** fold 1 ***********
# catboost model NMAE : 0.0378
# rf model NMAE : 0.0405
# gbr model NMAE : 0.0393
# ********************************
# Average NMAE 0.0385
#
# *********** fold 2 ***********
# catboost model NMAE : 0.0360
# rf model NMAE : 0.0367
# gbr model NMAE : 0.0331
# ********************************
# Average NMAE 0.0345
#
# *********** fold 3 ***********
# catboost model NMAE : 0.0323
# rf model NMAE : 0.0338
# gbr model NMAE : 0.0343
# ********************************
# Average NMAE 0.0335
#
# *********** fold 4 ***********
# catboost model NMAE : 0.0378
# rf model NMAE : 0.0340
# gbr model NMAE : 0.0341
# ********************************
# Average NMAE 0.0358
#
# *********** fold 5 ***********
# catboost model NMAE : 0.0381
# rf model NMAE : 0.0405
# gbr model NMAE : 0.0390
# ********************************
# Average NMAE 0.0387
#
# *********** fold 6 ***********
# catboost model NMAE : 0.0383
# rf model NMAE : 0.0374
# gbr model NMAE : 0.0366
# ********************************
# Average NMAE 0.0379
#
# *********** fold 7 ***********
# catboost model NMAE : 0.0369
# rf model NMAE : 0.0375
# gbr model NMAE : 0.0339
# ********************************
# Average NMAE 0.0362
#
# *********** fold 8 ***********
# catboost model NMAE : 0.0337
# rf model NMAE : 0.0333
# gbr model NMAE : 0.0335
# ********************************
# Average NMAE 0.0347
#
# *********** fold 9 ***********
# catboost model NMAE : 0.0362
# rf model NMAE : 0.0345
# gbr model NMAE : 0.0361
# ********************************
# Average NMAE 0.0341
#
# *********** fold 10 ***********
# catboost model NMAE : 0.0397
# rf model NMAE : 0.0366
# gbr model NMAE : 0.0366
# ********************************
# Average NMAE 0.0356

# %%
np.array(fold_target_pred).shape
# Out:
# (10, 436)

# %%
### average target pred ###
final_pred = np.array(fold_target_pred[0])
for i in range(1, len(fold_target_pred)):
    final_pred += fold_target_pred[i]

final_pred = final_pred/len(fold_target_pred)

# %%
fp = np.exp(final_pred)

# %%
fp[0:5]
# Out:
# array([20443384.09356805,  4875404.9915224 ,  7429557.06572777,
#         1107683.06120495,  2523627.20177296])

# %%
submission = pd.read_csv('data/sample_submission.csv')
submission.head()
# Out:
#    id  target
# 0   0       0
# 1   1       0
# 2   2       0
# 3   3       0
# 4   4       0

# %%
# 위에서 구한 예측값 넣기
submission['target'] = fp
submission.head()
# Out:
#    id        target
# 0   0  2.044338e+07
# 1   1  4.875405e+06
# 2   2  7.429557e+06
# 3   3  1.107683e+06
# 4   4  2.523627e+06

# %%
submission.shape
# Out:
# (436, 2)

# %%
#submission.to_csv('data/submit0610.csv', index=False)
